# %%
import numpy as np
import pandas as pd

pd.__version__
# Out:
# '3.0.6'

# %%
import matplotlib as mp
mp.__version__
# Out:
# '3.11.2'

# %%
data = pd.read_csv('car_fuel_efficiency_2026.csv')

# %%
data['fuel_type'].describe()
# Out:
# count        10000
# unique           3
# top       Gasoline
# freq          6913
# Name: fuel_type, dtype: object

# %%
data.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
asia_cars = data[data['origin'] == 'Asia']

# %%
asia_cars['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
median_value = data['horsepower'].median()

# %%
freq = data['horsepower'].mode()[0]

# %%
new_median = data['horsepower'].fillna(freq).median()

print('Old median = ', median_value, '\nThe most frequent = ', freq,'\nNew median = ', new_median)
# Out:
# Old median =  254.0
# The most frequent =  252.0
# New median =  252.0

# %%
X = asia_cars[['vehicle_weight','model_year']].head(7).to_numpy()
XTX = X.T@X
y = [1100, 1300, 800, 900, 1000, 1100, 1200]
w = np.linalg.inv(XTX)@X.T@y
w.sum()
# Out:
# np.float64(0.36919696904925486)
